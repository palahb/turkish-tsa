# %%
# Mount the Google Drve for getting dataset

from google.colab import drive
drive.mount('/content/drive')

# Change directory to the project directory

import os
os.chdir('/content/drive/MyDrive/turkish-tsa/')
# Out:
# Mounted at /content/drive

# %%
#Install the Hugging Face Transformers library:

# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.28.1-py3-none-any.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 90.9 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (23.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 100.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 29.6 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.11.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2.0.12)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.13.4 tokenizers-0.13.3 transformers-4.28.1

# %%
# Import the necessary modules:

import torch
import numpy as np
import pandas as pd
from torch.utils.data import DataLoader, Dataset
from transformers import BertTokenizerFast, BertForSequenceClassification, AdamW, get_linear_schedule_with_warmup

# %%
# Loading the pretrained BERTurk tokenizer:

tokenizer = BertTokenizerFast.from_pretrained("dbmdz/bert-base-turkish-cased")
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/60.0 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/251k [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/385 [00:00<?, ?B/s]

# %%
# Load the pre-trained  BERTurk model and prepare it for sequence classification:

num_labels = 3  # positive, negative, and neutral 
model = BertForSequenceClassification.from_pretrained("dbmdz/bert-base-turkish-cased", num_labels=num_labels)
# Out:
# Downloading pytorch_model.bin:   0%|          | 0.00/445M [00:00<?, ?B/s]
# Some weights of the model checkpoint at dbmdz/bert-base-turkish-cased were not used when initializing BertForSequenceClassification: ['cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.decoder.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-cased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Adding the [TAR] token to the tokenizer's vocabulary and resizing the model's embeddings:

tokenizer.add_tokens(["[TAR]"])
model.resize_token_embeddings(len(tokenizer))
# Out:
# Embedding(32001, 768)

# %%
# Defining a custom dataset class for sentient analysis:

class SentimentDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_length=128):
        self.texts = texts
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_length = max_length

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        text = self.texts[idx]
        label = self.labels[idx]

        encoding = self.tokenizer(text, add_special_tokens=False, max_length=self.max_length, truncation=True, padding='max_length')
        input_ids = encoding["input_ids"]
        attention_mask = encoding["attention_mask"]

        return {
            "input_ids": torch.tensor(input_ids, dtype=torch.long),
            "attention_mask": torch.tensor(attention_mask, dtype=torch.long),
            "label": torch.tensor(label, dtype=torch.long)
        }

# %%
# Create the train, validation, and test sets:
train_data = pd.read_csv("dataset/tar_dataset/tar_train_dataset.csv")
validation_data = pd.read_csv("dataset/tar_dataset/tar_validation_dataset.csv")
test_data = pd.read_csv("dataset/tar_dataset/tar_test_dataset.csv")

# Data whose sentence and targeted sentiment are different:
different_s_t_data = pd.read_csv("dataset/tar_dataset/tar_diff_s_t.csv")
# Data whose sentence and targeted sentiment are the same:
same_s_t_data = pd.read_csv("dataset/tar_dataset/tar_same_s_t.csv")
# Data whose targeted sentiment is 'positive':
positive_t_data = pd.read_csv("dataset/tar_dataset/tar_positive_t.csv")
# Data whose targeted sentiment is 'neutral':
neutral_t_data = pd.read_csv("dataset/tar_dataset/tar_neutral_t.csv")
# Data whose targeted sentiment is 'negative':
negative_t_data = pd.read_csv("dataset/tar_dataset/tar_negative_t.csv")
# Data whose sentence and targeted sentiments are 'positive':
positive_s_t_data = pd.read_csv("dataset/tar_dataset/tar_positive_s_t.csv")
# Data whose sentence and targeted sentiments are 'neutral':
neutral_s_t_data = pd.read_csv("dataset/tar_dataset/tar_neutral_s_t.csv")
# Data whose sentence and targeted sentiments are 'negative':
negative_s_t_data = pd.read_csv("dataset/tar_dataset/tar_negative_s_t.csv")

train_data.head()
# Out:
#                                                 Text  \
# 0  [CLS] tüm maaşı sana yatırıyorum bi hediye gön...
# 1  [CLS]  [TAR] trendyol [TAR]  para iademi sonun...
# 2     [CLS] napıyorsun sen??   [TAR] trendyol [TAR]
# 3  [CLS] kurumsal şirketlere hizmet verdiğimiz # ...
# 4  [CLS]  [TAR] trendyol [TAR] ’da külçe altına y...
#
#                                            Tweet URL Targeted Sentiment  \
# 0  https://twitter.com/empalii/status/12341991646...           negative
# 1  https://twitter.com/tosbaalice/status/12552710...           negative
# 2  https://twitter.com/aleynozhn/status/121720847...           negative
# 3  https://twitter.com/eitatli/status/12552572590...            neutral
# 4  https://twitter.com/eegns/status/1253457666669...            neutral
#
#   Sentence Sentiment    Target
# 0           negative  trendyol
# 1           positive  trendyol
# 2           negative  trendyol
# 3            neutral  turkcell
# 4           positive  trendyol

# %%
# For the T-BERT model, training, validation and test will be done by 
# using targeted sentiments:

train_texts = train_data["Text"]
train_labels = train_data["Targeted Sentiment"]
val_texts = validation_data["Text"]
val_labels = validation_data["Targeted Sentiment"]

test_texts = test_data["Text"]
test_labels = test_data["Targeted Sentiment"]

different_s_t_texts = different_s_t_data["Text"]
different_s_t_labels = different_s_t_data["Targeted Sentiment"]

same_s_t_texts = same_s_t_data["Text"]
same_s_t_labels = same_s_t_data["Targeted Sentiment"]

positive_t_texts = positive_t_data["Text"]
positive_t_labels = positive_t_data["Targeted Sentiment"]

neutral_t_texts = neutral_t_data["Text"]
neutral_t_labels = neutral_t_data["Targeted Sentiment"]

negative_t_texts = negative_t_data["Text"]
negative_t_labels = negative_t_data["Targeted Sentiment"]

positive_s_t_texts = positive_s_t_data["Text"]
positive_s_t_labels = positive_s_t_data["Targeted Sentiment"]

neutral_s_t_texts = neutral_s_t_data["Text"]
neutral_s_t_labels = neutral_s_t_data["Targeted Sentiment"]

negative_s_t_texts = negative_s_t_data["Text"]
negative_s_t_labels = negative_s_t_data["Targeted Sentiment"]

# %%
# Convert string labels to numerical values
label_mapping = {"negative": 0, "neutral": 1, "positive": 2}
train_labels = [label_mapping[label] for label in train_labels]
val_labels = [label_mapping[label] for label in val_labels]
test_labels = [label_mapping[label] for label in test_labels]
different_s_t_labels = [label_mapping[label] for label in different_s_t_labels]
same_s_t_labels = [label_mapping[label] for label in same_s_t_labels]
positive_t_labels = [label_mapping[label] for label in positive_t_labels]
negative_t_labels = [label_mapping[label] for label in negative_t_labels]
neutral_t_labels = [label_mapping[label] for label in neutral_t_labels]
positive_s_t_labels = [label_mapping[label] for label in positive_s_t_labels]
negative_s_t_labels = [label_mapping[label] for label in negative_s_t_labels]
neutral_s_t_labels = [label_mapping[label] for label in neutral_s_t_labels]

# Create SentimentDataset instances
train_dataset = SentimentDataset(train_texts, train_labels, tokenizer)
val_dataset = SentimentDataset(val_texts, val_labels, tokenizer)
test_dataset = SentimentDataset(test_texts, test_labels, tokenizer)
different_s_t_dataset = SentimentDataset(different_s_t_texts, different_s_t_labels, tokenizer)
same_s_t_dataset = SentimentDataset(same_s_t_texts, same_s_t_labels, tokenizer)
positive_t_dataset = SentimentDataset(positive_t_texts, positive_t_labels, tokenizer)
neutral_t_dataset = SentimentDataset(neutral_t_texts, neutral_t_labels, tokenizer)
negative_t_dataset = SentimentDataset(negative_t_texts, negative_t_labels, tokenizer)
positive_s_t_dataset = SentimentDataset(positive_s_t_texts, positive_s_t_labels, tokenizer)
neutral_s_t_dataset = SentimentDataset(neutral_s_t_texts, neutral_s_t_labels, tokenizer)
negative_s_t_dataset = SentimentDataset(negative_s_t_texts, negative_s_t_labels, tokenizer)

# Create DataLoader instances
batch_size = 24
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
different_s_t_loader = DataLoader(different_s_t_dataset, batch_size=batch_size, shuffle=False)
same_s_t_loader = DataLoader(same_s_t_dataset, batch_size=batch_size, shuffle=False)
positive_t_loader = DataLoader(positive_t_dataset, batch_size=batch_size, shuffle=False)
neutral_t_loader = DataLoader(neutral_t_dataset, batch_size=batch_size, shuffle=False)
negative_t_loader = DataLoader(negative_t_dataset, batch_size=batch_size, shuffle=False)
positive_s_t_loader = DataLoader(positive_s_t_dataset, batch_size=batch_size, shuffle=False)
neutral_s_t_loader = DataLoader(neutral_s_t_dataset, batch_size=batch_size, shuffle=False)
negative_s_t_loader = DataLoader(negative_s_t_dataset, batch_size=batch_size, shuffle=False)

# %%
# Set the device and move the model to the device:

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)

model = model.to(device)
# Out:
# Sun Apr 23 20:41:58 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    44W / 400W |      3MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# Get class counts for training dataset:

class_count_0 = train_labels.count(0)
class_count_1 = train_labels.count(1)
class_count_2 = train_labels.count(2)

def getKey(dict, value):
  return list(filter(lambda x: dict[x] == value, dict))[0]

print("Class counts:")
print(f"{getKey(label_mapping,0)}: {class_count_0}")
print(f"{getKey(label_mapping,1)}: {class_count_1}")
print(f"{getKey(label_mapping,2)}: {class_count_2}")
# Out:
# Class counts:
# negative: 1037
# neutral: 699
# positive: 464

# %%
# Set the class weights and define the loss function:

from torch import nn
import torch.nn.functional as F

class_weights = torch.tensor([1 / class_count_0, 1 / class_count_1, 1 / class_count_2]).to(device)
loss_fn = nn.CrossEntropyLoss(weight=class_weights)

# %%
# Prepare the optimizer and learning rate scheduler:

epochs = 18
num_training_steps = epochs * len(train_loader)
lr = 1e-5
weight_decay = 0.1
warmup_steps = 300

optimizer = AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)
scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=warmup_steps, num_training_steps=num_training_steps)
# Out:
# /usr/local/lib/python3.9/dist-packages/transformers/optimization.py:391: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
# Define helper functions for training and evaluation:

def train_epoch(model, data_loader, loss_fn, optimizer, device, scheduler):
    model = model.train()
    total_train_loss = 0
    
    for batch in data_loader:
        input_ids = batch["input_ids"].to(device)
        attention_mask = batch["attention_mask"].to(device)
        labels = batch["label"].to(device)

        outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
        loss = outputs.loss

        total_train_loss += loss.item()

        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()
        scheduler.step()
        optimizer.zero_grad()

    return total_train_loss / len(data_loader)

def eval_epoch(model, data_loader, loss_fn, device):
    model = model.eval()
    total_eval_loss = 0

    with torch.no_grad():
        for batch in data_loader:
            input_ids = batch["input_ids"].to(device)
            attention_mask = batch["attention_mask"].to(device)
            labels = batch["label"].to(device)

            outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
            loss = outputs.loss

            total_eval_loss += loss.item()

    return total_eval_loss / len(data_loader)

# %%
# Calculate performance metrics:

from sklearn.metrics import precision_recall_fscore_support

def get_predictions(model, data_loader, device):
    model = model.eval()
    predictions = []
    true_labels = []

    with torch.no_grad():
        for batch in data_loader:
            input_ids = batch["input_ids"].to(device)
            attention_mask = batch["attention_mask"].to(device)
            labels = batch["label"].to(device)

            outputs = model(input_ids, attention_mask=attention_mask)
            _, preds = torch.max(outputs.logits, dim=1)

            predictions.extend(preds.cpu().numpy().tolist())
            true_labels.extend(labels.cpu().numpy().tolist())

    return predictions, true_labels

def get_f1_scores(model, device):
    print("F1 Scores:")

    test_preds, test_labels = get_predictions(model, test_loader, device)
    test_f1 = precision_recall_fscore_support(test_labels, test_preds, average='weighted', zero_division=0)[2]
    print(f"\tTest dataset against targeted sentiment labels: {test_f1:.4f}")

    diff_s_t_preds, diff_s_t_labels = get_predictions(model, different_s_t_loader, device)
    diff_s_t_f1 = precision_recall_fscore_support(diff_s_t_labels, diff_s_t_preds, average='weighted', zero_division=0)[2]
    print(f"\tData whose targeted and sentence sentiment are different: {diff_s_t_f1:.4f}")

    same_s_t_preds, same_s_t_labels = get_predictions(model, same_s_t_loader, device)
    same_s_t_f1 = precision_recall_fscore_support(same_s_t_labels, same_s_t_preds, average='weighted', zero_division=0)[2]
    print(f"\tData whose targeted and sentence sentiment are the same: {same_s_t_f1:.4f}")

    positive_t_preds, positive_t_labels = get_predictions(model, positive_t_loader, device)
    positive_t_f1 = precision_recall_fscore_support(positive_t_labels, positive_t_preds, average='weighted', zero_division=0)[2]
    print(f"\tData whose targeted sentiment is 'positive': {positive_t_f1:.4f}")

    positive_s_t_preds, positive_t_labels = get_predictions(model, positive_s_t_loader, device)
    positive_s_t_f1 = precision_recall_fscore_support(positive_s_t_labels, positive_s_t_preds, average='weighted', zero_division=0)[2]
    print(f"\tData whose targeted sentiment and sentence sentiments are both 'positive': {positive_s_t_f1:.4f}")

    neutral_t_preds, neutral_t_labels = get_predictions(model, neutral_t_loader, device)
    neutral_t_f1 = precision_recall_fscore_support(neutral_t_labels, neutral_t_preds, average='weighted', zero_division=0)[2]
    print(f"\tData whose targeted sentiment is 'neutral': {neutral_t_f1:.4f}")

    neutral_s_t_preds, neutral_t_labels = get_predictions(model, neutral_s_t_loader, device)
    neutral_s_t_f1 = precision_recall_fscore_support(neutral_s_t_labels, neutral_s_t_preds, average='weighted', zero_division=0)[2]
    print(f"\tData whose targeted sentiment and sentence sentiments are both 'neutral': {neutral_s_t_f1:.4f}")

    negative_t_preds, negative_t_labels = get_predictions(model, negative_t_loader, device)
    negative_t_f1 = precision_recall_fscore_support(negative_t_labels, negative_t_preds, average='weighted', zero_division=0)[2]
    print(f"\tData whose targeted sentiment is 'negative': {negative_t_f1:.4f}")

    negative_s_t_preds, negative_t_labels = get_predictions(model, negative_s_t_loader, device)
    negative_s_t_f1 = precision_recall_fscore_support(negative_s_t_labels, negative_s_t_preds, average='weighted', zero_division=0)[2]
    print(f"\tData whose targeted sentiment and sentence sentiments are both 'negative': {negative_s_t_f1:.4f}")

    return test_f1, diff_s_t_f1, same_s_t_f1, positive_t_f1, positive_s_t_f1, neutral_t_f1, neutral_s_t_f1, negative_t_f1, negative_s_t_f1

# %%
import csv

f = open("./models/t-bert_marked/results.csv","w")
writer = csv.writer(f)
writer.writerow(["Epoch","Train loss", "Val. loss", "Test loss", "Test data F1",\
            "Diff. labels F1", "Same labels F1", "T=positive F1", "TS=positive F1",\
            "T=neutral F1", "TS=neutral F1", "T=negative F1", "TS=negative F1"])

# Train and evaluate the model:

for epoch in range(epochs):
    print("-" * 10)
    print(f"Epoch {epoch+1}/{epochs}")

    train_loss = train_epoch(model, train_loader, loss_fn, optimizer, device, scheduler)
    print(f"Train Loss: {train_loss:.4f}")

    val_loss = eval_epoch(model, val_loader, loss_fn, device)
    print(f"Validation Loss: {val_loss:.4f}")

    test_loss = "-"

    if (epoch+1) % 3 == 0:

        test_loss = eval_epoch(model, test_loader, loss_fn, device)
        print(f"Test Loss: {test_loss:.4f}")

        model.save_pretrained(f"./models/t-bert_marked/epoch{epoch+1}/model")
        tokenizer.save_pretrained(f"./models/t-bert_marked/epoch{epoch+1}/tokenizer")
        print("Saved.")

    test_f1, diff_s_t_f1, same_s_t_f1, positive_t_f1, positive_s_t_f1, \
    neutral_t_f1, neutral_s_t_f1, negative_t_f1, negative_s_t_f1 = get_f1_scores(model, device)

    writer.writerow([epoch+1,train_loss,val_loss,test_loss,test_f1, diff_s_t_f1, same_s_t_f1, positive_t_f1, \
               positive_s_t_f1, neutral_t_f1, neutral_s_t_f1, negative_t_f1, negative_s_t_f1])

f.close()
# Out:
# ----------
# Epoch 1/18
# Train Loss: 1.1293
# Validation Loss: 1.0267
# F1 Scores:
# 	Test dataset against targeted sentiment labels: 0.3506
# 	Data whose targeted and sentence sentiment are different: 0.1738
# 	Data whose targeted and sentence sentiment are the same: 0.4606
# 	Data whose targeted sentiment is 'positive': 0.0082
# 	Data whose targeted sentiment and sentence sentiments are both 'positive': 0.0042
# 	Data whose targeted sentiment is 'neutral': 0.2557
# 	Data whose targeted sentiment and sentence sentiments are both 'neutral': 0.2482
# 	Data whose targeted sentiment is 'negative': 0.9404
# 	Data whose targeted sentiment and sentence sentiments are both 'negative': 0.9404
# ----------
# Epoch 2/18
# Train Loss: 1.0434
# Validation Loss: 0.9915
# F1 Scores:
# 	Test dataset against targeted sentiment labels: 0.3571
# 	Data whose targeted and sentence sentiment are different: 0.1566
# 	Data whose targeted and sentence sentiment are the same: 0.4831
# 	Data whose targeted sentiment is 'positive': 0.0000
# 	Data whose targeted sentiment and sentence sentiments are both 'positive': 0.0000
# 	Data whose targeted sentiment is 'neutral': 0.2284
# 	Data whose targeted sentiment and sentence sentiments are both 'neutral': 0.2225
# 	Data whose targeted sentiment is 'negative': 0.9839
# 	Data whose targeted sentiment and sentence sentiments are both 'negative': 0.9861
# ----------
# Epoch 3/18
# Train Loss: 0.9760
# Validation Loss: 0.8948
# Test Loss: 0.9229
# Saved.
# F1 Scores:
# 	Test dataset against targeted sentiment labels: 0.4954
# 	Data whose targeted and sentence sentiment are different: 0.4090
# 	Data whose targeted and sentence sentiment are the same: 0.5821
# 	Data whose targeted sentiment is 'positive': 0.0562
# 	Data whose targeted sentiment and sentence sentiments are both 'positive': 0.0494
# 	Data whose targeted sentiment is 'neutral': 0.6902
# 	Data whose targeted sentiment and sentence sentiments are both 'neutral': 0.6718
# 	Data whose targeted sentiment is 'negative': 0.9356
# 	Data whose targeted sentiment and sentence sentiments are both 'negative': 0.9433
# ----------
# Epoch 4/18
# Train Loss: 0.8668
# Validation Loss: 0.8353
# F1 Scores:
# 	Test dataset against targeted sentiment labels: 0.5895
# 	Data whose targeted and sentence sentiment are different: 0.5108
# 	Data whose targeted and sentence sentiment are the same: 0.7131
# 	Data whose targeted sentiment is 'positive': 0.4746
# 	Data whose targeted sentiment and sentence sentiments are both 'positive': 0.5415
# 	Data whose targeted sentiment is 'neutral': 0.8276
# 	Data whose targeted sentiment and sentence sentiments are both 'neutral': 0.8394
# 	Data whose targeted sentiment is 'negative': 0.8856
# 	Data whose targeted sentiment and sentence sentiments are both 'negative': 0.9000
# ----------
# Epoch 5/18
# Train Loss: 0.7586
# Validation Loss: 0.7956
# F1 Scores:
# 	Test dataset against targeted sentiment labels: 0.6359
# 	Data whose targeted and sentence sentiment are different: 0.5471
# 	Data whose targeted and sentence sentiment are the same: 0.7888
# 	Data whose targeted sentiment is 'positive': 0.6299
# 	Data whose targeted sentiment and sentence sentiments are both 'positive': 0.7154
# 	Data whose targeted sentiment is 'neutral': 0.8225
# 	Data whose targeted sentiment and sentence sentiments are both 'neutral': 0.8449
# 	Data whose targeted sentiment is 'negative': 0.9290
# 	Data whose targeted sentiment and sentence sentiments are both 'negative': 0.9393
# ----------
# Epoch 6/18
# Train Loss: 0.6536
# Validation Loss: 0.8136
# Test Loss: 0.8317
# Saved.
# F1 Scores:
# 	Test dataset against targeted sentiment labels: 0.6339
# 	Data whose targeted and sentence sentiment are different: 0.6318
# 	Data whose targeted and sentence sentiment are the same: 0.8105
# 	Data whose targeted sentiment is 'positive': 0.7226
# 	Data whose targeted sentiment and sentence sentiments are both 'positive': 0.7954
# 	Data whose targeted sentiment is 'neutral': 0.8771
# 	Data whose targeted sentiment and sentence sentiments are both 'neutral': 0.8790
# 	Data whose targeted sentiment is 'negative': 0.9140
# 	Data whose targeted sentiment and sentence sentiments are both 'negative': 0.9255
# ----------
# Epoch 7/18
# Train Loss: 0.5624
# Validation Loss: 0.8284
# F1 Scores:
# 	Test dataset against targeted sentiment labels: 0.6516
# 	Data whose targeted and sentence sentiment are different: 0.6506
# 	Data whose targeted and sentence sentiment are the same: 0.8397
# 	Data whose targeted sentiment is 'positive': 0.7304
# 	Data whose targeted sentiment and sentence sentiments are both 'positive': 0.8015
# 	Data whose targeted sentiment is 'neutral': 0.8927
# 	Data whose targeted sentiment and sentence sentiments are both 'neutral': 0.9024
# 	Data whose targeted sentiment is 'negative': 0.9366
# 	Data whose targeted sentiment and sentence sentiments are both 'negative': 0.9462
# ----------
# Epoch 8/18
# Train Loss: 0.4692
# Validation Loss: 0.8760
# F1 Scores:
# 	Test dataset against targeted sentiment labels: 0.6517
# 	Data whose targeted and sentence sentiment are different: 0.7130
# 	Data whose targeted and sentence sentiment are the same: 0.8552
# 	Data whose targeted sentiment is 'positive': 0.8113
# 	Data whose targeted sentiment and sentence sentiments are both 'positive': 0.8660
# 	Data whose targeted sentiment is 'neutral': 0.9139
# 	Data whose targeted sentiment and sentence sentiments are both 'neutral': 0.9228
# 	Data whose targeted sentiment is 'negative': 0.9262
# 	Data whose targeted sentiment and sentence sentiments are both 'negative': 0.9345
# ----------
# Epoch 9/18
# Train Loss: 0.3828
# Validation Loss: 0.9310
# Test Loss: 0.9485
# Saved.
# F1 Scores:
# 	Test dataset against targeted sentiment labels: 0.6755
# 	Data whose targeted and sentence sentiment are different: 0.7225
# 	Data whose targeted and sentence sentiment are the same: 0.8739
# 	Data whose targeted sentiment is 'positive': 0.8834
# 	Data whose targeted sentiment and sentence sentiments are both 'positive': 0.9288
# 	Data whose targeted sentiment is 'neutral': 0.8562
# 	Data whose targeted sentiment and sentence sentiments are both 'neutral': 0.8622
# 	Data whose targeted sentiment is 'negative': 0.9516
# 	Data whose targeted sentiment and sentence sentiments are both 'negative': 0.9581
# ----------
# Epoch 10/18
# Train Loss: 0.3471
# Validation Loss: 0.9478
# F1 Scores:
# 	Test dataset against targeted sentiment labels: 0.6719
# 	Data whose targeted and sentence sentiment are different: 0.7407
# 	Data whose targeted and sentence sentiment are the same: 0.8840
# 	Data whose targeted sentiment is 'positive': 0.8730
# 	Data whose targeted sentiment and sentence sentiments are both 'positive': 0.9178
# 	Data whose targeted sentiment is 'neutral': 0.8944
# 	Data whose targeted sentiment and sentence sentiments are both 'neutral': 0.9063
# 	Data whose targeted sentiment is 'negative': 0.9486
# 	Data whose targeted sentiment and sentence sentiments are both 'negative': 0.9552
# ----------
# Epoch 11/18
# Train Loss: 0.2660
# Validation Loss: 1.0044
# F1 Scores:
# 	Test dataset against targeted sentiment labels: 0.6750
# 	Data whose targeted and sentence sentiment are different: 0.7657
# 	Data whose targeted and sentence sentiment are the same: 0.8965
# 	Data whose targeted sentiment is 'positive': 0.8634
# 	Data whose targeted sentiment and sentence sentiments are both 'positive': 0.9066
# 	Data whose targeted sentiment is 'neutral': 0.9122
# 	Data whose targeted sentiment and sentence sentiments are both 'neutral': 0.9199
# 	Data whose targeted sentiment is 'negative': 0.9606
# 	Data whose targeted sentiment and sentence sentiments are both 'negative': 0.9662
# ----------
# Epoch 12/18
# Train Loss: 0.2195
# Validation Loss: 1.0526
# Test Loss: 1.0785
# Saved.
# F1 Scores:
# 	Test dataset against targeted sentiment labels: 0.6844
# 	Data whose targeted and sentence sentiment are different: 0.7811
# 	Data whose targeted and sentence sentiment are the same: 0.8990
# 	Data whose targeted sentiment is 'positive': 0.9028
# 	Data whose targeted sentiment and sentence sentiments are both 'positive': 0.9360
# 	Data whose targeted sentiment is 'neutral': 0.9056
# 	Data whose targeted sentiment and sentence sentiments are both 'neutral': 0.9161
# 	Data whose targeted sentiment is 'negative': 0.9546
# 	Data whose targeted sentiment and sentence sentiments are both 'negative': 0.9609
# ----------
# Epoch 13/18
# Train Loss: 0.1755
# Validation Loss: 1.1073
# F1 Scores:
# 	Test dataset against targeted sentiment labels: 0.6758
# 	Data whose targeted and sentence sentiment are different: 0.7928
# 	Data whose targeted and sentence sentiment are the same: 0.9002
# 	Data whose targeted sentiment is 'positive': 0.8928
# 	Data whose targeted sentiment and sentence sentiments are both 'positive': 0.9264
# 	Data whose targeted sentiment is 'neutral': 0.9220
# 	Data whose targeted sentiment and sentence sentiments are both 'neutral': 0.9313
# 	Data whose targeted sentiment is 'negative': 0.9533
# 	Data whose targeted sentiment and sentence sentiments are both 'negative': 0.9592
# ----------
# Epoch 14/18
# Train Loss: 0.1574
# Validation Loss: 1.1655
# F1 Scores:
# 	Test dataset against targeted sentiment labels: 0.6757
# 	Data whose targeted and sentence sentiment are different: 0.8088
# 	Data whose targeted and sentence sentiment are the same: 0.9013
# 	Data whose targeted sentiment is 'positive': 0.8877
# 	Data whose targeted sentiment and sentence sentiments are both 'positive': 0.9178
# 	Data whose targeted sentiment is 'neutral': 0.9306
# 	Data whose targeted sentiment and sentence sentiments are both 'neutral': 0.9370
# 	Data whose targeted sentiment is 'negative': 0.9556
# 	Data whose targeted sentiment and sentence sentiments are both 'negative': 0.9609
# ----------
# Epoch 15/18
# Train Loss: 0.1260
# Validation Loss: 1.2126
# Test Loss: 1.2161
# Saved.
# F1 Scores:
# 	Test dataset against targeted sentiment labels: 0.6688
# 	Data whose targeted and sentence sentiment are different: 0.8055
# 	Data whose targeted and sentence sentiment are the same: 0.9039
# 	Data whose targeted sentiment is 'positive': 0.8851
# 	Data whose targeted sentiment and sentence sentiments are both 'positive': 0.9153
# 	Data whose targeted sentiment is 'neutral': 0.9306
# 	Data whose targeted sentiment and sentence sentiments are both 'neutral': 0.9388
# 	Data whose targeted sentiment is 'negative': 0.9580
# 	Data whose targeted sentiment and sentence sentiments are both 'negative': 0.9634
# ----------
# Epoch 16/18
# Train Loss: 0.1148
# Validation Loss: 1.2469
# F1 Scores:
# 	Test dataset against targeted sentiment labels: 0.6843
# 	Data whose targeted and sentence sentiment are different: 0.8131
# 	Data whose targeted and sentence sentiment are the same: 0.9065
# 	Data whose targeted sentiment is 'positive': 0.9020
# 	Data whose targeted sentiment and sentence sentiments are both 'positive': 0.9288
# 	Data whose targeted sentiment is 'neutral': 0.9225
# 	Data whose targeted sentiment and sentence sentiments are both 'neutral': 0.9276
# 	Data whose targeted sentiment is 'negative': 0.9606
# 	Data whose targeted sentiment and sentence sentiments are both 'negative': 0.9662
# ----------
# Epoch 17/18
